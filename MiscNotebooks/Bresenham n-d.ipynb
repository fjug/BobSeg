# %%
import bresenham as bham

# %%
s = np.array([[3, 1, 9]])
t = np.array([[0, -1, -2]])
bham.bresenhamline(s, t, max_iter=-1)
# Out:
# array([[ 3,  1,  8],
#        [ 2,  1,  7],
#        [ 2,  0,  6],
#        [ 2,  0,  5],
#        [ 2,  0,  4],
#        [ 1,  0,  3],
#        [ 1,  0,  2],
#        [ 1,  0,  1],
#        [ 1, -1,  0],
#        [ 0, -1, -1],
#        [ 0, -1, -2]])
